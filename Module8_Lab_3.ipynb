# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit-Duggal/FMML-2022-Aug/blob/main/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-23 13:19:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   192MB/s    in 0.4s
#
# 2023-05-23 13:19:18 (192 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29075  1708.03763v2  We have developed a deep learning network for ...    cs
# 33256   0709.0883v5                         Major mistakes do not read    cs
# 13133  1703.02690v1  The facility location problem is widely used f...  stat
# 40760   1305.2388v1  In the most intrusion detection systems (IDS),...    cs
# 22456  1607.07573v1  Mixture models with Gamma and or inverse-Gamma...  stat
# ...             ...                                                ...   ...
# 31898   1203.2557v3  This work explores the effects of relevant and...    cs
# 34369  1602.07618v1  In this paper we argue for a paradigmatic shif...    cs
# 26124  1608.07973v3  Linking two data sources is a basic building b...    cs
# 4458   1712.02658v1  This paper proposes the adaptation of Support ...  stat
# 22240  1509.08582v1  We consider the problem of transforming sample...  stat
#
#                                                    title  year  \
# 29075  Flower Categorization using Deep Convolutional...  2017
# 33256  Liquid State Machines in Adbiatic Quantum Comp...  2007
# 13133  Leveraging Sparsity for Efficient Submodular D...  2017
# 40760  Fast Feature Reduction in intrusion detection ...  2013
# 22456  Variational Mixture Models with Gamma or inver...  2016
# ...                                                  ...   ...
# 31898           On the Necessity of Irrelevant Variables  2012
# 34369  From quantum foundations via natural language ...  2016
# 26124             Linking Image and Text with 2-Way Nets  2016
# 4458     Using SVDD in SimpleMKL for 3D-Shapes Filtering  2017
# 22240  Tractable Fully Bayesian Inference via Convex ...  2015
#
#                                                 keywords
# 29075  [developed, classification, different, differe...
# 33256                           [computers, computation]
# 13133  [summarizing, additional, applications, placem...
# 40760  [intrusion, detection, characteristics, differ...
# 22456  [distributed, components, segmentation, regres...
# ...                                                  ...
# 31898  [irrelevant, variables, classifiers, assumptio...
# 34369  [paradigmatic, reductionism, togetherness, par...
# 26124  [canonical, correlation, utilizing, optimizer,...
# 4458   [adaptation, description, simplemkl, introduce...
# 22240  [transforming, continuous, distribution, distr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29075    [developed, classification, different, differe...
# 33256                             [computers, computation]
# 13133    [summarizing, additional, applications, placem...
# 40760    [intrusion, detection, characteristics, differ...
# 22456    [distributed, components, segmentation, regres...
#                                ...
# 38405    [comprehensive, frequencies, contemporary, det...
# 22465    [factorial, sequential, sequences, inference, ...
# 10813    [sublinear, algorithm, approximate, emphmaximu...
# 7407     [classification, applications, especially, cla...
# 22852    [stochastic, developed, algorithms, theoretica...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8696 words.
# Out of those 4579 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b021e23a-5e99-4494-b33d-680540743861" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b021e23a-5e99-4494-b33d-680540743861")) {                    Plotly.newPlot(                        "b021e23a-5e99-4494-b33d-680540743861",                        [{"x":["applications","implemented","enthusiasts","categorization","performance","extremely","different","googlenet","convolutional","architectures","university","basically","accuracies","developed","classification","parameters","segmentation","respectively","computation","computers","limitation","necessary","sparsified","placement","difficulty","sensitive","demonstrating","approximation","calculate","calculation","clustering","sparsification","summaries","algorithms","accelerate","infeasible","retrieval","assumptions","generates","submodular","summarizing","computations","leveraging","guarantees","efficient","similarities","interpretable","additional","summarization","optimization","establish","regularly","experimental","characteristics","reduction","differences","similarity","recommended","classifier","including","information","algorithm","evaluated","regression","recommendations","selection","classifiers","eliminate","intrusion","coefficient","compression","analyzing","outperform","successful","computational","superiority","detection","correlation","redundant","essential","activations","introduce","approaches","synthetic","considering","distributed","specially","solutions","represents","presented","methodology","occasionally","regularization","overestimate","separation","activation","inference","generalised","coefficients","expensive","likelihood","analytical","variational","furthermore","components","stochastic","framework","acceptable","resolution","accurately","distributions","empirical","philosophy","variables","estimated","underlying","reliability","predictions","recovered","forecasts","objective","estimation","polynomial","implementation","assigning","expressed","practical","empirically","heteroskedastic","statistical","uncertainties","probabilistic","continuous","dependent","dimensional","variances","consistent","selecting","combination","posterior","computationally","interleaved","procedure","graphical","expectation","component","probability","parameter","maximization","asymptotic","structure","variation","shrinkage","predictive","structured","neighborhood","spatially","predictors","simulated","demonstrate","effective","theoretical","hyperplane","controlling","exponential","designing","approximate","challenging","optimizes","approximately","prediction","guarantee","crowdsourcing","perceptron","attentive","throughout","traditional","achieving","significant","evaluates","evaluation","concentrates","mechanism","attention","appealing","recognizes","attracted","character","transcripts","normalized","recurrent","investigate","characters","community","benchmarks","relatively","intrinsic","recognize","comparable","mechanisms"],"y":[435,104,2,23,910,49,801,5,381,116,13,9,26,226,500,247,205,91,153,19,22,62,0,9,42,72,33,117,28,19,146,3,7,641,20,13,109,67,42,8,5,29,37,59,414,31,30,129,21,337,59,5,367,94,91,53,139,3,165,245,692,808,135,106,17,127,125,10,9,24,41,73,108,84,285,34,356,70,16,72,21,335,416,162,66,95,10,144,64,183,75,1,80,4,28,33,230,6,23,80,61,26,69,155,106,136,561,14,121,65,130,151,10,131,65,120,19,74,16,1,157,199,57,128,14,45,158,78,0,144,9,157,96,79,198,5,91,48,150,52,108,4,123,62,31,96,180,134,28,18,347,67,5,57,125,39,14,5,66,531,238,157,1,18,49,46,124,258,13,27,212,46,14,18,10,21,187,71,206,10,281,4,125,165,18,7,31,47,5,27,143,129,24,87,107,53,33,58,76,56],"type":"bar"},{"x":["applications","implemented","enthusiasts","categorization","performance","extremely","different","go ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4579,), (4579, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Who</span> <span style=''>did</span> <span style=''>What</span> <span style=''>A</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Person</span> <span style=''>Centered</span> <span style=''>Cloze</span> <span style=''>Dataset</span> <br/><br/><span style=''>We</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Who</span> <span style=''>did</span> <span style=''>What</span> <span style=''>dataset</span> <span style=''>of</span> <span style=''>over</span> <span style=''>200000</span> <span style=''>fill</span> <span style=''>in</span> <span style=''>the</span> <span style=''>gap</span> <span style=''>(cloze)</span> <span style=''>multiple</span> <span style=''>choice</span> <span style=''>reading</span> <span style='background-color:rgba(0, 255, 0, 0.6842105263157894);'>comprehension</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>the</span> <span style=''>LDC</span> <span style=''>English</span> <span style=''>Gigaword</span> <span style=''>newswire</span> <span style=''>corpus</span> <span style=''>The</span> <span style=''>WDW</span> <span style=''>dataset</span> <span style=''>has</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>novel</span> <span style=''>features</span> <span style=''>First</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>with</span> <span style=''>the</span> <span style=''>CNN</span> <span style=''>and</span> <span style=''>Daily</span> <span style=''>Mail</span> <span style=''>datasets</span> <span style=''>(Hermann</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2015)</span> <span style=''>we</span> <span style=''>avoid</span> <span style=''>using</span> <span style=''>article</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>summaries</span> <span style=''>for</span> <span style=''>question</span> <span style='background-color:rgba(0, 255, 0, 0.7500000000000001);'>formation</span> <span style=''>Instead</span> <span style=''>each</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>formed</span> <span style=''>from</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>articles</span> <span style=''>an</span> <span style=''>article</span> <span style=''>given</span> <span style=''>as</span> <span style=''>the</span> <span style=''>passage</span> <span style=''>to</span> <span style=''>be</span> <span style=''>read</span> <span style=''>and</span> <span style=''>a</span> <span style=''>separate</span> <span style=''>article</span> <span style=''>on</span> <span style=''>the</span> <span style=''>same</span> <span style=''>events</span> <span style=''>used</span> <span style=''>to</span> <span style=''>form</span> <span style=''>the</span> <span style=''>question</span> <span style=''>Second</span> <span style=''>we</span> <span style=''>avoid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anonymization</span> <span style=''>each</span> <span style=''>choice</span> <span style=''>is</span> <span style=''>a</span> <span style=''>person</span> <span style=''>named</span> <span style=''>entity</span> <span style=''>Third</span> <span style=''>the</span> <span style=''>problems</span> <span style=''>have</span> <span style=''>been</span> <span style=''>filtered</span> <span style=''>to</span> <span style=''>remove</span> <span style=''>a</span> <span style=''>fraction</span> <span style=''>that</span> <span style=''>are</span> <span style=''>easily</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>baselines</span> <span style=''>while</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymptotic</span> <span style=''>Analysis</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equations</span> <span style=''>of</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Paradigms</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigates</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behaviors</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>(particularly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerated</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent)</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>arose</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>can</span> <span style=''>be</span> <span style=''>modeled</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>ordinary</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolutions</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>are</span> <span style=''>governed</span> <span style=''>by</span> <span style=''>some</span> <span style=''>linear</span> <span style=''>ordinary</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equations</span> <span style=''>as</span> <span style=''>the</span> <span style=''>data</span> <span style=''>size</span> <span style=''>goes</span> <span style=''>to</span> <span style=''>infinity</span> <span style=''>We</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>Introduction</span> <span style=''>to</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Class</span> <span style=''>Notes</span> <span style=''>67577</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3846153846153846);'>Introduction</span> <span style=''>to</span> <span style=''>Machine</span> <span style=''>learning</span> <span style=''>covering</span> <span style='background-color:rgba(255, 0, 0, 0.35426008968609857);'>Statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>(Bayes</span> <span style=''>EM</span> <span style=''>MLMaxEnt</span> <span style=''>duality)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algebraic</span> <span style=''>and</span> <span style=''>spectral</span> <span style=''>methods</span> <span style=''>(PCA</span> <span style=''>LDA</span> <span style=''>CCA</span> <span style=''>Clustering)</span> <span style=''>and</span> <span style=''>PAC</span> <span style=''>learning</span> <span style=''>(the</span> <span style=''>Formal</span> <span style=''>model</span> <span style=''>VC</span> <span style='background-color:rgba(255, 0, 0, 0.31658291457286436);'>dimension</span> <span style=''>Double</span> <span style=''>Sampling</span> <span style=''>theorem)</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Curvature</span> <span style=''>aided</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Incremental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Aggregated</span> <span style=''>Gradient</span> <span style=''>Method</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>finite</span> <span style=''>sum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>aided</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregated</span> <span style=''>gradient</span> <span style=''>(CIAG)</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>training</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style=''>a</span> <span style=''>d</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>training</span> <span style=''>data</span> <span style=''>is</span> <span style=''>m</span> <span style=''>and</span> <span style=''>m</span> <span style=''>gg</span> <span style=''>d</span> <span style=''>gg</span> <span style=''>1</span> <span style=''>the</span> <span style=''>CIAG</span> <span style=''>method</span> <span style=''>seeks</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregated</span> <span style=''>gradient</span> <span style=''>(IAG)</span> <span style=''>methods</span> <span style=''>using</span> <span style=''>aids</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>(or</span> <span style=''>Hessian)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>while</span> <span style=''>avoiding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>matrix</span> <span style=''>inverses</span> <span style=''>required</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style=''>Newton</span> <span style=''>(IN)</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>our</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incrementally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregated</span> <span style=''>Hessian</span> <span style=''>matrix</span> <span style=''>to</span> <span style=''>trace</span> <span style=''>the</span> <span style=''>full</span> <span style=''>gradient</span> <span style=''>vector</span> <span style=''>at</span> <span style=''>every</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style=''>step</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.0841726618705036)
# 	processing (0.10683453237410072)
# 	evaluation (0.10107913669064748)
# 	segmentation (0.0737410071942446)
# 	representation (0.1316546762589928)
# 	information (0.2489208633093525)
# 	detection (0.12805755395683452)
# 	recognition (0.1356115107913669)
# 	convolutional (0.1370503597122302)
# 	different (0.2881294964028777)
#
# Some Statistics words are:
# 	variables (0.13465346534653466)
# 	theoretical (0.14455445544554454)
# 	stochastic (0.13762376237623763)
# 	estimation (0.1603960396039604)
# 	algorithm (0.38613861386138615)
# 	statistical (0.1495049504950495)
# 	inference (0.18465346534653465)
# 	distribution (0.18217821782178217)
# 	dimensional (0.1792079207920792)
# 	regression (0.17524752475247524)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5ae47f73-2057-4ead-b532-fc73d5164aa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ae47f73-2057-4ead-b532-fc73d5164aa9")) {                    Plotly.newPlot(                        "5ae47f73-2057-4ead-b532-fc73d5164aa9",                        [{"x":["applications","implemented","enthusiasts","categorization","performance","extremely","different","googlenet","convolutional","architectures","university","basically","accuracies","developed","classification","parameters","segmentation","respectively","computation","computers","limitation","necessary","sparsified","placement","difficulty","sensitive","demonstrating","approximation","calculate","calculation","clustering","sparsification","summaries","algorithms","accelerate","infeasible","retrieval","assumptions","generates","submodular","summarizing","computations","leveraging","guarantees","efficient","similarities","interpretable","additional","summarization","optimization","establish","regularly","experimental","characteristics","reduction","differences","similarity","recommended","classifier","including","information","algorithm","evaluated","regression","recommendations","selection","classifiers","eliminate","intrusion","coefficient","compression","analyzing","outperform","successful","computational","superiority","detection","correlation","redundant","essential","activations","introduce","approaches","synthetic","considering","distributed","specially","solutions","represents","presented","methodology","occasionally","regularization","overestimate","separation","activation","inference","generalised","coefficients","expensive","likelihood","analytical","variational","furthermore","components","stochastic","framework","acceptable","resolution","accurately","distributions","empirical","philosophy","variables","estimated","underlying","reliability","predictions","recovered","forecasts","objective","estimation","polynomial","implementation","assigning","expressed","practical","empirically","heteroskedastic","statistical","uncertainties","probabilistic","continuous","dependent","dimensional","variances","consistent","selecting","combination","posterior","computationally","interleaved","procedure","graphical","expectation","component","probability","parameter","maximization","asymptotic","structure","variation","shrinkage","predictive","structured","neighborhood","spatially","predictors","simulated","demonstrate","effective","theoretical","hyperplane","controlling","exponential","designing","approximate","challenging","optimizes","approximately","prediction","guarantee","crowdsourcing","perceptron","attentive","throughout","traditional","achieving","significant","evaluates","evaluation","concentrates","mechanism","attention","appealing","recognizes","attracted","character","transcripts","normalized","recurrent","investigate","characters","community","benchmarks","relatively","intrinsic","recognize","comparable","mechanisms","efficiently","properties","connectionist","recognition","simultaneously","interests","cognition","experiments","particular","convergence","inequalities","independently","infinitely","deviation","martingale","distribution","divisible","distributional","conditional","supervised","knowledge","covariances","arbitrarily","constraints","dimension","impossibility","nontrivial","structural","parametric","dimensions","fundamental","attainable","densities","ineffective","importance","describes","challenge","competition","individual","potential","describing","competitive","engineering","attractiveness","personalized","aggregated","afterwards","according","purchases","recovering","occurrences","prominent","relatedness","categories","represent","individuals","intuitively","anal ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sparsified
# 	heteroskedastic
# 	reciprocity
# 	robustify
# 	statistic
# 	regressionclassification
# 	mcallester
# 	thermodynamics
# 	oscillates
# 	censoring
# 	varepsilon
# 	uncontaminated
# 	zebrafish
# 	invertible
# 	nomination
# 	unnecessarily
# 	polymorphisms
# 	nucleotide
# 	blockmodels
# 	bijective
# Some words which never appear in Statistics papers:
# 	enthusiasts
# 	googlenet
# 	interleaved
# 	attentive
# 	transcripts
# 	connectionist
# 	attractiveness
# 	inefficiency
# 	naturalistic
# 	syntactic
# 	argumentation
# 	justifications
# 	analogies
# 	determinism
# 	obfuscating
# 	cityscapes
# 	formalisms
# 	unexpectedly
# 	functionalities
# 	destinations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.08842150776738e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
